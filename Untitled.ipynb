# %%
import pandas as pd
import numpy as np

# %%
happiness = pd.read_csv("2019.csv")
happiness
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
trade = pd.read_csv("trade.csv")
trade
# Out:
#       LOCATION Reporter country FLOW     Flow PARTNER Partner country  \
# 0          AUS        Australia  EXP  Exports     AUT         Austria
# 1          AUS        Australia  EXP  Exports     AUT         Austria
# 2          AUS        Australia  EXP  Exports     AUT         Austria
# 3          AUS        Australia  EXP  Exports     AUT         Austria
# 4          AUS        Australia  EXP  Exports     AUT         Austria
# ...        ...              ...  ...      ...     ...             ...
# 23215      NZL      New Zealand  IMP  Imports     NZL     New Zealand
# 23216      NZL      New Zealand  IMP  Imports     NZL     New Zealand
# 23217      NZL      New Zealand  IMP  Imports     NZL     New Zealand
# 23218      NZL      New Zealand  IMP  Imports     NZL     New Zealand
# 23219      NZL      New Zealand  IMP  Imports     NZL     New Zealand
#
#       FREQUENCY  Frequency     TIME     Time Unit Code       Unit  \
# ...

# %%
trade2022 = trade[trade['TIME'] == "2022-Q3"]
trade2022
# Out:
#       LOCATION Reporter country FLOW     Flow PARTNER Partner country  \
# 6          AUS        Australia  EXP  Exports     AUT         Austria
# 14         AUS        Australia  EXP  Exports     BEL         Belgium
# 22         AUS        Australia  EXP  Exports     CAN          Canada
# 30         AUS        Australia  EXP  Exports     CZE  Czech Republic
# 38         AUS        Australia  EXP  Exports     DNK         Denmark
# ...        ...              ...  ...      ...     ...             ...
# 23189      USA    United States  EXP  Exports    OECD    OECD - Total
# 23197      GRC           Greece  EXP  Exports     G-7              G7
# 23205      DNK          Denmark  IMP  Imports    G-20             G20
# 23213      IRL          Ireland  IMP  Imports     IRL         Ireland
# 23218      NZL      New Zealand  IMP  Imports     NZL     New Zealand
#
#       FREQUENCY  Frequency     TIME     Time Unit Code       Unit  \
# ...

# %%
exports = trade2022[trade2022['Flow'] == "Exports"]
exports
# Out:
#       LOCATION Reporter country FLOW     Flow PARTNER Partner country  \
# 6          AUS        Australia  EXP  Exports     AUT         Austria
# 14         AUS        Australia  EXP  Exports     BEL         Belgium
# 22         AUS        Australia  EXP  Exports     CAN          Canada
# 30         AUS        Australia  EXP  Exports     CZE  Czech Republic
# 38         AUS        Australia  EXP  Exports     DNK         Denmark
# ...        ...              ...  ...      ...     ...             ...
# 23146      CAN           Canada  EXP  Exports    OECD    OECD - Total
# 23163      CHE      Switzerland  EXP  Exports     G-7              G7
# 23181      PRT         Portugal  EXP  Exports    G-20             G20
# 23189      USA    United States  EXP  Exports    OECD    OECD - Total
# 23197      GRC           Greece  EXP  Exports     G-7              G7
#
#       FREQUENCY  Frequency     TIME     Time Unit Code       Unit  \
# ...

# %%
df = exports[['Reporter country', "Partner country", "Value"]]
df
# Out:
#       Reporter country Partner country         Value
# 6            Australia         Austria      13727145
# 14           Australia         Belgium     277156583
# 22           Australia          Canada     378309096
# 30           Australia  Czech Republic      12425070
# 38           Australia         Denmark      44953922
# ...                ...             ...           ...
# 23146           Canada    OECD - Total  137838511140
# 23163      Switzerland              G7   45256541291
# 23181         Portugal             G20   17112251664
# 23189    United States    OECD - Total  365636814954
# 23197           Greece              G7    4103894097
#
# [1468 rows x 3 columns]

# %%
exports['Partner country'].value_counts()
# Out:
# Korea                           33
# G7                              33
# World                           33
# South Africa                    33
# Indonesia                       33
# India                           33
# China (People's Republic of)    33
# Brazil                          33
# Austria                         32
# Switzerland                     32
# Türkiye                         32
# United Kingdom                  32
# United States                   32
# Argentina                       32
# Estonia                         32
# Chile                           32
# Belgium                         32
# Israel                          32
# Saudi Arabia                    32
# Slovenia                        32
# Australia                       32
# Sweden                          32
# Spain                           32
# Slovak Republic                 32
# Denmark                         32
# France                          32
# Germany                         32
# ...

# %%
final = df[df["Partner country"].isin(df['Reporter country'].value_counts().index)]
final
# Out:
#       Reporter country Partner country      Value
# 6            Australia         Austria   13727145
# 14           Australia         Belgium  277156583
# 22           Australia          Canada  378309096
# 30           Australia  Czech Republic   12425070
# 38           Australia         Denmark   44953922
# ...                ...             ...        ...
# 10730         Slovenia  United Kingdom  183524633
# 10737         Slovenia   United States  226556521
# 10758         Slovenia           Chile    3044794
# 10772         Slovenia         Estonia   17049776
# 10793         Slovenia          Israel   24635447
#
# [1053 rows x 3 columns]

# %%
countries = pd.Series(final['Reporter country'].value_counts().index)
countries
# Out:
# 0           Australia
# 1             Austria
# 2              Israel
# 3             Estonia
# 4       United States
# 5      United Kingdom
# 6             Türkiye
# 7         Switzerland
# 8              Sweden
# 9               Spain
# 10    Slovak Republic
# 11           Portugal
# 12             Poland
# 13             Norway
# 14        Netherlands
# 15           Slovenia
# 16         Luxembourg
# 17              Japan
# 18            Belgium
# 19             Canada
# 20     Czech Republic
# 21            Denmark
# 22            Finland
# 23             France
# 24            Germany
# 25             Greece
# 26            Hungary
# 27            Iceland
# 28            Ireland
# 29              Italy
# 30              Chile
# 31        New Zealand
# 32             Mexico
# dtype: object
